# %%
import pandas as pd
import numpy as np

# %%
n1 = {"Monday":[2,3,4,5],"Tuesday":[6,7,8,9]}
n2 = {"Wednusday":{"ALA":30,"CA":60},"Thursday":{"EWASTE":4,"RM":2}}
n3 = {5:"Friday",6:"Saturday"}

print(pd.DataFrame(n1),'\n')

#pd.DataFrame(n1,n2) # n2 is considered row index of n1 

print(pd.DataFrame(n1,n2,n3),'\n') # n3 is considered column index of n1

print(pd.DataFrame(n2),'\n')
print(pd.DataFrame(n3),'\n')
# Out:
#    Monday  Tuesday
# 0       2        6
# 1       3        7
# 2       4        8
# 3       5        9
#
#              5    6
# Wednusday  NaN  NaN
# Thursday   NaN  NaN
#
#         Wednusday  Thursday
# ALA          30.0       NaN
# CA           60.0       NaN
# EWASTE        NaN       4.0
# RM            NaN       2.0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 12
#       9 print(pd.DataFrame(n1,n2,n3),'\n') # n3 is considered column index of n1
#      11 print(pd.DataFrame(n2),'\n')
# ---> 12 print(pd.DataFrame(n3),'\n')
#
# File c:\Users\fbase\All_vscode_projects\PandasGithubRepo\.venv\Lib\site-packages\pandas\core\frame.py:769, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     763     mgr = self._init_mgr(
#     764         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     765     )
#     767 elif isinstance(data, dict):
#     768     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 769     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy)
#     770 elif isinstance(data, ma.MaskedArray):
#     771     from numpy.ma import mrecords
#
# File c:\Users\fbase\All_vscode_projects\PandasGithubRepo\.venv\Lib\site-packages\pandas\core\internals\construction.py:460, in dict_to_mgr(data, index, columns, dtype, copy)
#     441 if copy:
#     442     # We only need to copy arrays that will not get consolidated, i.e.
#     443     #  only EA arrays
#     444     arrays = [
#     445         (
#     446             x.copy()
#    (...)    457         for x in arrays
#     458     ]
# --> 460 return arrays_to_mgr(arrays, columns, index, dtype=dtype, consolidate=copy)
#
# File c:\Users\fbase\All_vscode_projects\PandasGithubRepo\.venv\Lib\site-packages\pandas\core\internals\construction.py:113, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, consolidate)
#     110 if verify_integrity:
#     111     # figure out the index, if necessary
#     112     if index is None:
# --> 113         index = _extract_index(arrays)
#     114     else:
#     115         index = ensure_index(index)
#
# File c:\Users\fbase\All_vscode_projects\PandasGithubRepo\.venv\Lib\site-packages\pandas\core\internals\construction.py:634, in _extract_index(data)
#     631         raise ValueError("Per-column arrays must each be 1-dimensional")
#     633 if not indexes and not raw_lengths:
# --> 634     raise ValueError("If using all scalar values, you must pass an index")
#     636 if have_series:
#     637     index = union_indexes(indexes)
#
# ValueError: If using all scalar values, you must pass an index

# %% [markdown]
# ## Phase 1: Advanced DataFrame Operations (Questions 1-8)
# 1. Create DataFrame from nested dictionary
# 2. Create DataFrame with MultiIndex
# 3. Create DataFrame from list of tuples
# 4. Create DataFrame with custom dtypes
# 5. Create DataFrame with datetime index and time zones
# 6. Create DataFrame from SQL query result (simulated)
# 7. Create DataFrame with categorical data
# 8. Create DataFrame with hierarchical columns
